# %%
from categorize_identifiers import dir2, variables

# %%
import numpy as np 
import pandas as pd
import datetime

d = 1
b = 2
c = 3.14
d = 'hello'
e = b'hello\x00'
f = bytearray(b'hello\x00')
g = (1, 2, 3)
h = [1, 2, 3, 4]
i = {'r': 'red', 'g': 'green', 'b': 'blue'}
j = datetime.datetime.now()
k = np.array([0, 1, 2, 3, 4])
l = np.array([[1, 2, 3],
              [4, 5, 6]])
df = pd.DataFrame({'colors': ['red', 'green', 'blue']})
s = df['colors']
index = df.index

# %%
variables()
# Out:
#                     Type Size/Shape                                    Value
# Instance Name
# d                    str          5                                    hello
# b                    int                                                   2
# c                  float                                                3.14
# e                  bytes          6                             b'hello\x00'
# f              bytearray          6                  bytearray(b'hello\x00')
# g                  tuple          3                                (1, 2, 3)
# h                   list          4                             [1, 2, 3, 4]
# i                   dict          3  {'r': 'red', 'g': 'green', 'b': 'blue'}
# k                ndarray       (5,)                          [0, 1, 2, 3, 4]
# l                ndarray     (2, 3)                   [[1, 2, 3], [4, 5, 6]]
# df             DataFrame     (3, 1)                                 [colors]
# ...

# %%
dir2(__builtins__)
