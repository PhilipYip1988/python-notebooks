# %%
    tau = 2 * np.pi
    theta = np.linspace(0, tau, 100)
    r = np.ones(100)
    theta2 = (0, tau/8)
    r2 = (0, 1)
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
    ax.plot(theta, r, color='royalblue')
    ax.plot(theta2, r2, color='red')
    
    xticks = ax.xaxis.get_ticklocs()
    xticklabels = [r'$\frac{' + f'{num}' + '}{8}$' + r'$\tau$' for num in range(8)]
    ax.xaxis.set_ticks(xticks)
    ax.set_xticklabels(xticklabels) 
    ax.set_rticks([0, 0.5, 1])
    ax.set_rlabel_position(45)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ax.xaxis.get_ticklocs()
# Out:
# array([0.        , 0.78539816, 1.57079633, 2.35619449, 3.14159265,
#        3.92699082, 4.71238898, 5.49778714])

# %%
import math

# %%
x1 = list(range(0, 6))
y1 = list(map(math.factorial, x1))

x2 = (np.arange(1, 6.1, 0.1)).tolist()
y2 = list(map(math.gamma, x2)) 
x2 = np.arange(1, 6.1, 0.1) - 1

fig, ax = plt.subplots()
ax.scatter(x1, y1, color='tomato', label='n!')
ax.plot(x2, y2, color='royalblue', label=r'$\Gamma$(n+1)')
ax.set_label('n')
ax.legend()

# %%
y1
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
list(map(math.gamma, x2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 list(map(math.gamma, x2))
#
# ValueError: math domain error

# %%
x1 = list(range(0, 11))
y1 = list(map(math.factorial, x1))

x2 = (np.arange(1, 11.1, 0.1)).tolist()
y2 = list(map(math.gamma, x2)) 
x2 = np.arange(1, 11.1, 0.1) - 1

fig, ax = plt.subplots()
ax.scatter(x1, y1, color='tomato', label='n!')
ax.plot(x2, y2, color='royalblue', label=r'$\Gamma$(n+1)')
ax.set_label('n')
ax.legend()
ax.set_yscale('log')

# %%
fig, ax = plt.subplots(subplot_kw={'aspect':'equal'})
ax.set_xlim(left=0, right=6)
ax.set_ylim(bottom=0, top=6)
ax.grid()
x1 = (1, 1)
y1 = (1, 5)
x2 = (1, 4)
y2 = (1, 1)
x3 = (4, 1)
y3 = (1, 5)
ax.plot(x1, y1, color='mediumpurple', lw=2, ls=':')
ax.plot(x2, y2, color='darkorange', lw=2, ls=':')
ax.plot(x3, y3, color='seagreen', lw=2, ls=':')
ax.spines[['bottom', 'left', 'top', 'right']].set_visible(False)
ax.tick_params(axis='both', which='both', length=0)

# %%
import math
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'3d', 'aspect':'equal'})
x1 = (3,)
y1 = (4,)
z1 = (7,)
x2 = (1, 3)
y2 = (1, 1)
z2 = (1, 1)
x3 = (1, 1)
y3 = (1, 4)
z3 = (1, 1)
x4 = (1, 1)
y4 = (1, 1)
z4 = (1, 7)
x5 = (1, 3)
y5 = (1, 4)
z5 = (1, 7)
ax.scatter3D(x1, y1, z1, s=50, color='tomato')
ax.plot3D(x2, y2, z2, color='darkorange', lw=2, ls=':')
ax.plot3D(x3, y3, z3, color='mediumpurple', lw=2, ls=':')
ax.plot3D(x4, y4, z4, color='cyan', lw=2, ls=':')
ax.plot3D(x5, y5, z5, color='seagreen', lw=2, ls='-')
ax.set_xlim(left=0, right=7)
ax.set_ylim(bottom=0, top=7)
ax.set_zlim(bottom=0, top=7)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_xlabel('z')
# Out:
# (0.0, 7.0)

# %%
? ax.set_zlim
# Out:
# Signature:
#  ax.set_zlim(
#     bottom=None,
#     top=None,
#     *,
#     emit=True,
#     auto=False,
#     zmin=None,
#     zmax=None,
# )
# Docstring:
# Set 3D z limits.
#
# See `.Axes.set_ylim` for full documentation
# File:      c:\users\philip\mambaforge\envs\vscode\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py
# Type:      method

# %%
tau = math.pi * 2
fig, ax = plt.subplots(subplot_kw={'aspect':'equal'})
r = 1
theta = np.arange(-tau, tau, 0.1)
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, color='tomato')
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlim(left=-1.5, right=1.5)
ax.set_ylim(bottom=-1.5, top=1.5)
ax.set_xlabel('x')
ax.set_ylabel('y')

ax.set_x
# Out:
# Text(0, 0.5, 'y')

# %%
angle = 2*tau/16
theta = np.linspace(0, tau, 100)
r = np.ones(100)
theta2 = (0, angle)
r2 = (0, 1)
theta3 = (angle,)
r3 = (1,)
theta4 = (0, 0)
r4 = (0, math.cos(angle))
theta5 = (0, angle)
r5 = (math.cos(angle), 1)
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r, color='royalblue')
ax.plot(theta2, r2, color='tomato') 
ax.scatter(theta3, r3, s=50, color='tomato')
ax.plot(theta4, r4, color='magenta', lw=2, ls=':')
ax.plot(theta5, r5, color='cyan', lw=2, ls=':')
xticks = np.linspace(0, 90, 5)
xticklabels = [r'$\frac{' + f'{num}' + '}{16}$' + r'$\tau$' for num in range(5)]
ax.set_thetagrids(xticks)
ax.set_xticklabels(xticklabels) 
ax.set_rticks([0, 0.5, 1])
ax.set_rlabel_position(45)
ax.set_thetamin(0)
ax.set_thetamax(90)
theta6 = 0
r6 = 0
ax.annotate('adjacent',
            xy=(0.1, math.cos(angle)/2-0.02),  # theta, radius
            xytext=(0.1, math.cos(angle)/2-0.02),
            color='magenta')
ax.annotate('opposite',
            xy=(angle-0.5, math.cos(angle)-0.02),  # theta, radius
            xytext=(angle-0.5, math.cos(angle)-0.02),
            color='cyan', rotation=90)
ax.annotate('hypotenuse',
            xy=(angle-0.1, math.cos(angle)/2-0.01),  # theta, radius
            xytext=(angle-0.1, math.cos(angle)/2-0.01),
            color='red', rotation=45)
ax.annotate(r'$\theta$',
            xy=(0.3, 0.1),  # theta, radius
            xytext=(0.3, 0.1),
            color='black')
# Out:
# Text(0.3, 0.1, '$\\theta$')

# %%
theta = np.linspace(0, tau, 100)
r = np.ones(100)

#theta3 = (math.sin(4*tau/8),)
#r3 = (1,)

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r, color='royalblue')

ax.scatter(theta3, r3, s=50, color='tomato')

xticks = np.linspace(0, 90, 5)
xticklabels = [r'$\frac{' + f'{num}' + '}{16}$' + r'$\tau$' for num in range(5)]
ax.set_thetagrids(xticks)
ax.set_xticklabels(xticklabels) 
ax.set_rticks([0, 0.5, 1])
ax.set_rlabel_position(45)
ax.set_thetamin(0)
ax.set_thetamax(90)

theta6 = 0
r6 = 0

ax.annotate('adjacent',
            xy=(0.1, math.cos(2*tau/16)/2-0.02),  # theta, radius
            xytext=(0.1, math.cos(2*tau/16)/2-0.02),
            color='magenta')

ax.annotate('opposite',
            xy=(1.0*tau/16, math.sin(2*tau/16)),  # theta, radius
            xytext=(1.0*tau/16, math.sin(2*tau/16)),
            color='cyan', rotation=90)

ax.annotate(r'$\theta$',
            xy=(0.3, 0.1),  # theta, radius
            xytext=(0.3, 0.1),
            color='black')

ax.scatter(0*tau/16, 1)
ax.scatter(1*tau/16, 1)
ax.scatter(2*tau/16, 1)
ax.scatter(3*tau/16, 1)
ax.scatter(4*tau/16, 1)

# %%
np.linspace(0, 90, 5) / 360
# Out:
# array([0.    , 0.0625, 0.125 , 0.1875, 0.25  ])

# %%
math.cos(tau/16)
# Out:
# 0.9238795325112867

# %%
ax.xaxis.get
# Out:
# array([0.        , 0.26179939, 0.52359878, 0.78539816, 1.04719755,
#        1.30899694, 1.57079633])

# %%
# Out:
# (<a list of 10 Line2D ticklines objects>,
#  [Text(0.0, 0, '0°'),
#   Text(0.39269908169872414, 0, '22°'),
#   Text(0.7853981633974483, 0, '45°'),
#   Text(1.1780972450961724, 0, '68°'),
#   Text(1.5707963267948966, 0, '90°')])

# %%
theta = np.linspace(0, tau, 100)
r = np.ones(100)
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r, color='royalblue')
ax.set_thetamin(0)
ax.set_thetamax(90)
ax.scatter(0*tau/16, 1)
ax.scatter(1*tau/16, 1)
ax.scatter(2*tau/16, 1)
ax.scatter(3*tau/16, 1)
ax.scatter(4*tau/16, 1)

xticks = np.linspace(0, 90, 5)
xticklabels = [r'$\frac{' + f'{num}' + '}{16}$' + r'$\tau$' for num in range(5)]
ax.set_thetagrids(xticks)
ax.set_xticklabels(xticklabels)
# Out:
# [Text(0.0, 0, '$\\frac{0}{16}$$\\tau$'),
#  Text(0.39269908169872414, 0, '$\\frac{1}{16}$$\\tau$'),
#  Text(0.7853981633974483, 0, '$\\frac{2}{16}$$\\tau$'),
#  Text(1.1780972450961724, 0, '$\\frac{3}{16}$$\\tau$'),
#  Text(1.5707963267948966, 0, '$\\frac{4}{16}$$\\tau$')]

# %%
np.linspace(0, 90, 5)
# Out:
# array([ 0. , 22.5, 45. , 67.5, 90. ])
