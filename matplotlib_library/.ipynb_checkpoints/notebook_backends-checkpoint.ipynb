# %% [markdown]
# # Backends Test

# %% [markdown]
# ## Library Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Backend

# %% [markdown]
# The backend may not change correctly until the kernel is restarted. Select only one of the three options:

# %%
# %matplotlib notebook

# %%
# %matplotlib qt5

# %%
# %matplotlib ipympl

# %% [markdown]
# ## Data

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0.001, 2.001, 3.999, 5.999, 8.002, 10.001])

# %% [markdown]
# ## Plot

# %%
fig, ax = plt.subplots(num=1);
ax.plot(x, y, color='tomato');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
